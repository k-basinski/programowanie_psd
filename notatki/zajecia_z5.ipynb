# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

df = pd.read_csv("stroke.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   object
#  4   heart_disease      5110 non-null   object
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 479.2+ KB

# %%
df.head()
# Out:
#       id  gender   age  ...   bmi   smoking_status stroke
# 0   9046    Male  67.0  ...  36.6  formerly smoked    yes
# 1  51676  Female  61.0  ...   NaN     never smoked    yes
# 2  31112    Male  80.0  ...  32.5     never smoked    yes
# 3  60182  Female  49.0  ...  34.4           smokes    yes
# 4   1665  Female  79.0  ...  24.0     never smoked    yes
#
# [5 rows x 12 columns]

# %%
pearsonr(df.age, df.avg_glucose_level)
# Out:
# (0.23817111410174327, 7.856310807798251e-67)

# %%
sns.relplot(x='age', y='avg_glucose_level', data=df)

# %%
sns.relplot(x='age', y='avg_glucose_level', data=df, alpha=.1)

# %%
sns.relplot(x='age', y='avg_glucose_level', data=df, alpha=.5)

# %%
sns.relplot(x='age', y='avg_glucose_level', hue='stroke', data=df)

# %%
sns.relplot(x='age', y='avg_glucose_level', hue='stroke', data=df, alpha=.3)

# %%
sns.relplot(x='age', y='avg_glucose_level', hue='stroke', data=df)

# %%
sns.relplot(x='age', y='avg_glucose_level', kind='line', data=df)

# %%
sns.relplot(x='age', y='avg_glucose_level', kind='line', hue='stroke', data=df)

# %%
df.stroke.value_counts()
# Out:
# no     4861
# yes     249
# Name: stroke, dtype: int64

# %%
sns.displot(data=df, x='bmi')

# %%
udary = df[df.stroke == 'yes']

# %%
sns.displot(data=udary, x='bmi', binwidth=1)

# %%
sns.displot(data=df, x='age', hue='stroke', kind='kde')

# %%
sns.scatterplot(x='age', y='avg_glucose_level',  data=df)
sns.rugplot(x='age', y='avg_glucose_level',  data=df)

# %%
sns.set_palette("viridis")
sns.jointplot(x='age', y='avg_glucose_level', kind='hex', data=df)

# %%
sns.catplot(x='stroke', y='avg_glucose_level', kind='bar', data=df)

# %%
sns.catplot(y='stroke', x='avg_glucose_level', kind='violin', data=df)

# %%
udary
# Out:
#         id  gender   age  ...   bmi   smoking_status stroke
# 0     9046    Male  67.0  ...  36.6  formerly smoked    yes
# 1    51676  Female  61.0  ...   NaN     never smoked    yes
# 2    31112    Male  80.0  ...  32.5     never smoked    yes
# 3    60182  Female  49.0  ...  34.4           smokes    yes
# 4     1665  Female  79.0  ...  24.0     never smoked    yes
# ..     ...     ...   ...  ...   ...              ...    ...
# 244  17739    Male  57.0  ...  36.7          Unknown    yes
# 245  49669  Female  14.0  ...  30.9          Unknown    yes
# 246  27153  Female  75.0  ...  29.3  formerly smoked    yes
# 247  34060    Male  71.0  ...   NaN          Unknown    yes
# 248  43424  Female  78.0  ...  19.6          Unknown    yes
#
# [249 rows x 12 columns]

# %%
sns.catplot(y='hypertension', x='age', data=udary, kind='swarm')

# %%
sns.catplot(x='stroke', y='avg_glucose_level', hue='hypertension', kind='violin', data=df)

# %%
sns.set_palette("twilight")
sns.catplot(x='stroke', y='bmi', hue='hypertension', kind='violin', data=df)

# %%
g = sns.FacetGrid(df, col="stroke")
g.map(sns.scatterplot, "age", "bmi")

# %%
g = sns.FacetGrid(df, col="stroke", row='hypertension')
g.map(sns.scatterplot, "age", "avg_glucose_level", alpha=.3)
plt.savefig("wykres.png", dpi=300)
